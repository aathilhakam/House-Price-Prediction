# %%
import string

import numpy as np
import pandas as pd

import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df = pd.read_csv('spam_ham_dataset.csv')
df.head()
# Out:
#    Unnamed: 0  ... label_num
# 0         605  ...         0
# 1        2349  ...         0
# 2        3624  ...         0
# 3        4685  ...         1
# 4        2030  ...         0
#
# [5 rows x 4 columns]

# %%
df['text'] = df['text'].apply(lambda x:x.replace('\n',''))

# %%
df.text.iloc[2]
# Out:
# "Subject: neon retreat\rho ho ho , we ' re around to that most wonderful time of the year - - - neon leaders retreat time !\ri know that this time of year is extremely hectic , and that it ' s tough to think about anything past the holidays , but life does go on past the week of december 25 through january 1 , and that ' s what i ' d like you to think about for a minute .\ron the calender that i handed out at the beginning of the fall semester , the retreat was scheduled for the weekend of january 5 - 6 . but because of a youth ministers conference that brad and dustin are connected with that week , we ' re going to change the date to the following weekend , january 12 - 13 . now comes the part you need to think about .\ri think we all agree that it ' s important for us to get together and have some time to recharge our batteries before we get to far into the spring semester , but it can be a lot of trouble and difficult for us to get away without kids , etc . so , brad came up with a potential alternative for how we can get together on that weekend , and then you can let me know which you prefer .\rthe first option would be to have a retreat similar to what we ' ve done the past several years . this year we could go to the heartland country inn ( www . . com ) outside of brenham . it ' s a nice place , where we ' d have a 13 - bedroom and a 5 - bedroom house side by side . it ' s in the country , real relaxing , but also close to brenham and only about one hour and 15 minutes from here . we can golf , shop in the antique and craft stores in brenham , eat dinner together at the ranch , and spend time with each other . we ' d meet on saturday , and then return on sunday morning , just like what we ' ve done in the past .\rthe second option would be to stay here in houston , have dinner together at a nice restaurant , and then have dessert and a time for visiting and recharging at one of our homes on that saturday evening . this might be easier , but the trade off would be that we wouldn ' t have as much time together . i ' ll let you decide .\remail me back with what would be your preference , and of course if you ' re available on that weekend . the democratic process will prevail - - majority vote will rule ! let me hear from you as soon as possible , preferably by the end of the weekend . and if the vote doesn ' t go your way , no complaining allowed ( like i tend to do ! )\rhave a great weekend , great golf , great fishing , great shopping , or whatever makes you happy !\rbobby"

# %%
df
# Out:
#       Unnamed: 0  ... label_num
# 0            605  ...         0
# 1           2349  ...         0
# 2           3624  ...         0
# 3           4685  ...         1
# 4           2030  ...         0
# ...          ...  ...       ...
# 5166        1518  ...         0
# 5167         404  ...         0
# 5168        2933  ...         0
# 5169        1409  ...         0
# 5170        4807  ...         1
#
# [5171 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5171 entries, 0 to 5170
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5171 non-null   int64
#  1   label       5171 non-null   object
#  2   text        5171 non-null   object
#  3   label_num   5171 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 161.7+ KB

# %%
stemmer = PorterStemmer()
corpus = []

stopwords_set = set(stopwords.words('english'))

for i in range(len(df)):
  text = df['text'].iloc[i].lower()
  text = text.translate(str.maketrans('','', string.punctuation)).split()
  text = [stemmer.stem(word) for word in text if word not in stopwords_set]
  text = ' '.join(text)
  corpus.append(text)

# %%
df.text.iloc[0]
# Out:
# "Subject: enron methanol ; meter # : 988291\rthis is a follow up to the note i gave you on monday , 4 / 3 / 00 { preliminary\rflow data provided by daren } .\rplease override pop ' s daily volume { presently zero } to reflect daily\ractivity you can obtain from gas control .\rthis change is needed asap for economics purposes ."

# %%
corpus[0]
# Out:
# 'subject enron methanol meter 988291 follow note gave monday 4 3 00 preliminari flow data provid daren pleas overrid pop daili volum present zero reflect daili activ obtain ga control chang need asap econom purpos'

# %%
vectorizer = CountVectorizer()

x = vectorizer.fit_transform(corpus).toarray()
y = df.label_num

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = .02)

# %%
clf = RandomForestClassifier(n_jobs=-1)
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1)

# %%
clf.score(x_test, y_test)
# Out:
# 0.9807692307692307

# %%
email_to_classify = df.text.values[10]
email_to_classify
# Out:
# "Subject: vocable % rnd - word asceticism\rvcsc - brand new stock for your attention\rvocalscape inc - the stock symbol is : vcsc\rvcsc will be our top stock pick for the month of april - stock expected to\rbounce to 12 cents level\rthe stock hit its all time low and will bounce back\rstock is going to explode in next 5 days - watch it soar\rwatch the stock go crazy this and next week .\rbreaking news - vocalscape inc . announces agreement to resell mix network\rservices\rcurrent price : $ 0 . 025\rwe expect projected speculative price in next 5 days : $ 0 . 12\rwe expect projected speculative price in next 15 days : $ 0 . 15\rvocalscape networks inc . is building a company that ' s revolutionizing the\rtelecommunications industry with the most affordable phone systems , hardware ,\ronline software , and rates in canada and the us . vocalscape , a company with\rglobal reach , is receiving international attention for the development of voice\rover ip ( voip ) application solutions , including the award - winning eyefontm , a\rsoftphone for real - time pc - to - phone . we are an advanced implementer of pbx\rsystems for companies , call centers , itsps and service providers .\rvocalscape has created software and interactive solutions revolving around\rglobal communications and data voice convergence . companies use vocalscape for\rvoice over internet protocol applications like ip pbxs , softswitches , pc 2 phone\rand web 2 phone , providing real - time human interaction and information delivery\rover the internet . through vocalscape ' s solutions , businesses can offer a\rquality voice service to anywhere in the world at rates that are significantly\rlower than current long distance charges . we develop software to run voip\rnetworks , and sell , install and service our own branded voip gateways and\rgatekeeper control software . we also license our software to customers who want\rto brand their own voip solutions .\rvocalscape is committed to making great technology ; challenging the status quo ,\rand building a 21 st century company that changes the way businesses communicate\rand interact through the internet .\rcurrent price : $ 0 . 025\rwe expect projected speculative price in next 5 days : $ 0 . 12\rwe expect projected speculative price in next 15 days : $ 0 . 15\rbreaking news - vocalscape inc . announces agreement to resell mix network\rservices\r- - - - - - - - - -\rkatonah , n . y . , / prnewswire - firstcall via comtex / - - vocalscape , inc . pink : vcsc ) ,\ran emerging leader in the development of voice over internet protocol ( voip )\rtelephony solutions , announced today it has entered into a sales agent agreement\rwith mix networks , inc . a voip enhanced telephony service provider .\rthis agreement provides vocalscape ' s turnkey calling card customers with access\rto mix networks services including north american dids ( phone numbers ) and\rdomestic long distance termination . vocalscape will also be able to supply their\rclients with enhanced voip products including pre - paid calling through mix\rnetworks north american network .\rwe are excited to help companies launch voip business models using our solution\rwith the whole picture from the software to the network needed to route the\rcalls . mix networks gives us the ability to offer wholesale monthly flat rate\rplans and dids to our clients that allow for us to build business models like\rpopular voip companies such as vonage and packet 8 , says ryan gibson , vp\rvocalscape networks\rsome legal words before you continue :\rinformation within this email contains forward looking statements within the\rmeaning of section 27 a of the securities act of 1933 and section 21 b of the\rsecurities exchange act of 1934 . any statements that express or involve\rdiscussions with respect to predictions , goals , expectations , beliefs , plans ,\rprojections , objectives , assumptions or future events or performance are not\rstatements of historical fact and may be for ...

# %%
email_text = email_to_classify.lower().translate(str.maketrans('','', string.punctuation)).split()
email_text = [stemmer.stem(word) for word in email_text if word not in stopwords_set]
email_text = ' '.join(email_text)

email_corpus = [email_text]

x_email = vectorizer.transform(email_corpus)

# %%
clf.predict(x_email)
# Out:
# array([1])

# %%
df.label_num.iloc[10]
# Out:
# np.int64(1)
